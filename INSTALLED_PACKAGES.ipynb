# %% [markdown]
# # Installed packages

# %% [markdown]
# Here is the list of packages that are already installed for you in this environment:

# %%
# !conda list
# Out:
# # packages in environment at /opt/conda:
# #
# _license                  1.1                      py36_1
# alabaster                 0.7.9                    py36_0
# anaconda                  custom                   py36_0
# anaconda-client           1.6.0                    py36_0
# anaconda-navigator        1.5.0                    py36_0
# anaconda-project          0.4.1                    py36_0
# astroid                   1.4.9                    py36_0
# astropy                   1.3                 np111py36_0
# babel                     2.3.4                    py36_0
# backports                 1.0                      py36_0
# beautifulsoup4            4.5.3                    py36_0
# bitarray                  0.8.1                    py36_0
# blaze                     0.10.1                   py36_0
# bokeh                     0.12.4                   py36_0
# boto                      2.45.0                   py36_0
# ...

# %%
# !pip list
# Out:
# DEPRECATION: The default format will switch to columns in the future. You can use --format=(legacy|columns) (or define a format=(legacy|columns) in your pip.conf under the [list] section) to disable this warning.
# alabaster (0.7.9)
# anaconda-client (1.6.0)
# anaconda-navigator (1.5)
# anaconda-project (0.4.1)
# astroid (1.4.9)
# astropy (1.3)
# Babel (2.3.4)
# backports.shutil-get-terminal-size (1.0.0)
# beautifulsoup4 (4.5.3)
# bitarray (0.8.1)
# blaze (0.10.1)
# bokeh (0.12.4)
# boto (2.45.0)
# Bottleneck (1.2.0)
# cffi (1.9.1)
# chardet (2.3.0)
# chest (0.2.3)
# click (6.7)
# cloudpickle (0.2.2)
# clyent (1.2.2)
# colorama (0.3.7)
# conda (4.3.14)
# configobj (5.0.6)
# contextlib2 (0.5.4)
# cryptography (1.7.1)
# cycler (0.10.0)
# Cython (0.25.2)
# cytoolz (0.8.2)
# dask (0.13.0)
# datashape (0.5.4)
# decorator (4.0.11)
# dill (0.2.5)
# docutils (0.13.1)
# et-xmlfile (1.0.1)
# fastcache (1.0.2)
# Flask (0.12)
# Flask-Cors (3.0.2)
# gevent (1.2.1)
# greenlet (0.4.11)
# ...

# %% [markdown]
# Most importantly, there are:

# %%
import numpy as np
import pandas as pd 
import scipy
import matplotlib

import sklearn
import lightgbm
import xgboost

for p in [np, pd, sklearn, matplotlib, scipy, lightgbm]:
    print (p.__name__, p.__version__)
# Out:
# numpy 1.13.1
# pandas 0.20.3
# sklearn 0.19.0
# matplotlib 2.0.2
# scipy 0.19.1
# lightgbm 2.0.6
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # How to install more packages

# %% [markdown]
# You can ***try*** to install new packages in the environment. You can do it like that:
#
#
# `conda intall <package>`
#
# or
#
# ```
# pip install <package>
# ```.
#
# However, Coursera does not expect you to do so. The packages you install may dissapear i.e. one day you open the notebooks and you cannot import a package, that you surely have istalled. In that case just install the package again or do everything locally.
#
# But anyway, for programming assignments you will not need to install any extra packages.
